# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd 
import numpy as np

# %%
# import data 
best_seller = pd.read_csv("bestsellers with categories.csv")
best_seller
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
best_seller.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
best_seller.tail()
# Out:
#                                                   Name       Author  \
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 545          4.9     9413      8  2019      Fiction
# 546          4.7    14331      8  2016  Non Fiction
# 547          4.7    14331      8  2017  Non Fiction
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction

# %% [markdown]
# # Describe data

# %%
# Attribute 
best_seller.dtypes
# Out:
# Name            object
# Author          object
# User Rating    float64
# Reviews          int64
# Price            int64
# Year             int64
# Genre           object
# dtype: object

# %%
best_seller.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
best_seller.index
# Out:
# RangeIndex(start=0, stop=550, step=1)

# %%
best_seller.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
best_seller.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
best_seller.mean()
# Out:
# User Rating        4.618364
# Reviews        11953.281818
# Price             13.100000
# Year            2014.000000
# dtype: float64

# %%
best_seller.sum()
# Out:
# Name           10-Day Green Smoothie Cleanse11/22/63: A Novel...
# Author         JJ SmithStephen KingJordan B. PetersonGeorge O...
# User Rating                                               2540.1
# Reviews                                                  6574305
# Price                                                       7205
# Year                                                     1107700
# Genre          Non FictionFictionNon FictionFictionNon Fictio...
# dtype: object

# %%
best_seller["Price"].sum()
# Out:
# 7205

# %%
best_seller["Year"].sum()
# Out:
# 1107700

# %%
best_seller["Reviews"].sum()
# Out:
# 6574305

# %%
best_seller["User Rating"].sum()
# Out:
# 2540.1000000000004

# %%
len("Reviews")
# Out:
# 7

# %% [markdown]
# # Viewing and selelcting data

# %% [markdown]
# # LOC  &. ILOC

# %%
best_seller = pd.Series(["Name", "Author", "User Rating", "Reviews", "Price", "Year", "Genre"])

best_seller
# Out:
# 0           Name
# 1         Author
# 2    User Rating
# 3        Reviews
# 4          Price
# 5           Year
# 6          Genre
# dtype: object

# %%
best_seller.loc[3]
# Out:
# 'Reviews'

# %%
best_seller.iloc[3]
# Out:
# 'Reviews'

# %%
best_seller
# Out:
# 0           Name
# 1         Author
# 2    User Rating
# 3        Reviews
# 4          Price
# 5           Year
# 6          Genre
# dtype: object

# %%
best_seller.loc[:3]
# Out:
# 0           Name
# 1         Author
# 2    User Rating
# 3        Reviews
# dtype: object

# %%
best_seller.iloc[:3]
# Out:
# 0           Name
# 1         Author
# 2    User Rating
# dtype: object

# %%
best_seller.head()
# Out:
# 0           Name
# 1         Author
# 2    User Rating
# 3        Reviews
# 4          Price
# dtype: object

# %%
best_seller.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-ab7408311e74> in <module>
# ----> 1 best_seller.columns
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5460             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5461                 return self[name]
# -> 5462             return object.__getattribute__(self, name)
#    5463
#    5464     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
best_seller[best_seller["Name"] > 3.0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-91-d8b71faa9bdf> in <module>
# ----> 1 best_seller[best_seller["Name"] > 3.0]
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     822
#     823         elif key_is_scalar:
# --> 824             return self._get_value(key)
#     825
#     826         if is_hashable(key):
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     930
#     931         # Similar to Index.get_value, but we do not fall back to positional
# --> 932         loc = self.index.get_loc(label)
#     933         return self.index._get_values_for_loc(self, loc, label)
#     934
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
# ...

# %%
best_seller = pd.read_csv("bestsellers with categories.csv")
best_seller
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
best_seller
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
pd.crosstab(best_seller["Name"], best_seller["Author"])
# Out:
# Author                                              Abraham Verghese  \
# Name
# 10-Day Green Smoothie Cleanse                                      0
# 11/22/63: A Novel                                                  0
# 12 Rules for Life: An Antidote to Chaos                            0
# 1984 (Signet Classics)                                             0
# 5,000 Awesome Facts (About Everything!) (Nation...                 0
# ...                                                              ...
# Winter of the World: Book Two of the Century Tr...                 0
# Women Food and God: An Unexpected Path to Almos...                 0
# Wonder                                                             0
# Wrecking Ball (Diary of a Wimpy Kid Book 14)                       0
# You Are a Badass: How to Stop Doubting Your Gre...                 0
#
# Author                                              Adam Gasiewski  \
# Name
# ...

# %%
best_seller["Name"]
# Out:
# 0                          10-Day Green Smoothie Cleanse
# 1                                      11/22/63: A Novel
# 2                12 Rules for Life: An Antidote to Chaos
# 3                                 1984 (Signet Classics)
# 4      5,000 Awesome Facts (About Everything!) (Natio...
#                              ...
# 545         Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546    You Are a Badass: How to Stop Doubting Your Gr...
# 547    You Are a Badass: How to Stop Doubting Your Gr...
# 548    You Are a Badass: How to Stop Doubting Your Gr...
# 549    You Are a Badass: How to Stop Doubting Your Gr...
# Name: Name, Length: 550, dtype: object

# %%
best_seller["Author"]
# Out:
# 0                      JJ Smith
# 1                  Stephen King
# 2            Jordan B. Peterson
# 3                 George Orwell
# 4      National Geographic Kids
#                  ...
# 545                 Jeff Kinney
# 546                 Jen Sincero
# 547                 Jen Sincero
# 548                 Jen Sincero
# 549                 Jen Sincero
# Name: Author, Length: 550, dtype: object

# %%
best_seller["User Rating"]
# Out:
# 0      4.7
# 1      4.6
# 2      4.7
# 3      4.7
# 4      4.8
#       ...
# 545    4.9
# 546    4.7
# 547    4.7
# 548    4.7
# 549    4.7
# Name: User Rating, Length: 550, dtype: float64

# %%
best_seller["Reviews"]
# Out:
# 0      17350
# 1       2052
# 2      18979
# 3      21424
# 4       7665
#        ...
# 545     9413
# 546    14331
# 547    14331
# 548    14331
# 549    14331
# Name: Reviews, Length: 550, dtype: int64

# %%
best_seller['Year']
# Out:
# 0      2016
# 1      2011
# 2      2018
# 3      2017
# 4      2019
#        ...
# 545    2019
# 546    2016
# 547    2017
# 548    2018
# 549    2019
# Name: Year, Length: 550, dtype: int64

# %% [markdown]
# # Group by

# %%
best_seller.groupby(["Reviews"]).mean()
# Out:
#          User Rating      Price     Year
# Reviews
# 37               4.6   6.000000  2009.00
# 220              4.6  17.000000  2013.00
# 408              4.5  20.000000  2010.00
# 438              4.5  15.000000  2009.00
# 440              4.4  11.000000  2010.00
# ...              ...        ...      ...
# 50482            4.7  11.500000  2013.25
# 57271            4.0   9.666667  2013.00
# 61133            4.8  11.000000  2018.50
# 79446            4.1  12.500000  2015.50
# 87841            4.8  15.000000  2019.00
#
# [346 rows x 3 columns]

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
best_seller["User Rating"].plot()
# Out:
# <AxesSubplot:>

# %%
best_seller["Reviews"].hist()
# Out:
# <AxesSubplot:>

# %%
best_seller["Price"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Manipulation  Data

# %%
best_seller["Name"].str.lower()
# Out:
# 0                          10-day green smoothie cleanse
# 1                                      11/22/63: a novel
# 2                12 rules for life: an antidote to chaos
# 3                                 1984 (signet classics)
# 4      5,000 awesome facts (about everything!) (natio...
#                              ...
# 545         wrecking ball (diary of a wimpy kid book 14)
# 546    you are a badass: how to stop doubting your gr...
# 547    you are a badass: how to stop doubting your gr...
# 548    you are a badass: how to stop doubting your gr...
# 549    you are a badass: how to stop doubting your gr...
# Name: Name, Length: 550, dtype: object

# %%
best_seller
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
best_seller["Name"] = best_seller["Name"].str.lower()

best_seller["Name"]
# Out:
# 0                          10-day green smoothie cleanse
# 1                                      11/22/63: a novel
# 2                12 rules for life: an antidote to chaos
# 3                                 1984 (signet classics)
# 4      5,000 awesome facts (about everything!) (natio...
#                              ...
# 545         wrecking ball (diary of a wimpy kid book 14)
# 546    you are a badass: how to stop doubting your gr...
# 547    you are a badass: how to stop doubting your gr...
# 548    you are a badass: how to stop doubting your gr...
# 549    you are a badass: how to stop doubting your gr...
# Name: Name, Length: 550, dtype: object

# %%
best_seller["User Rating"].mean()
# Out:
# 4.618363636363637

# %%
best_seller.dropna()
# Out:
#                                                   Name  \
# 0                        10-day green smoothie cleanse
# 1                                    11/22/63: a novel
# 2              12 rules for life: an antidote to chaos
# 3                               1984 (signet classics)
# 4    5,000 awesome facts (about everything!) (natio...
# ..                                                 ...
# 545       wrecking ball (diary of a wimpy kid book 14)
# 546  you are a badass: how to stop doubting your gr...
# 547  you are a badass: how to stop doubting your gr...
# 548  you are a badass: how to stop doubting your gr...
# 549  you are a badass: how to stop doubting your gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
best_seller.dropna(inplace = True)
best_seller
# Out:
#                                                   Name  \
# 0                        10-day green smoothie cleanse
# 1                                    11/22/63: a novel
# 2              12 rules for life: an antidote to chaos
# 3                               1984 (signet classics)
# 4    5,000 awesome facts (about everything!) (natio...
# ..                                                 ...
# 545       wrecking ball (diary of a wimpy kid book 14)
# 546  you are a badass: how to stop doubting your gr...
# 547  you are a badass: how to stop doubting your gr...
# 548  you are a badass: how to stop doubting your gr...
# 549  you are a badass: how to stop doubting your gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...
